# %%
import numpy as np
import pandas as pd
import requests
import xlsxwriter
import math
import datetime
import socket
from datetime import datetime, timedelta
import requests_cache

# %%
>>> from trading_ig.rest import IGService
>>> from trading_ig.config import config
>>> ig_service = IGService(config.username, config.password, config.api_key)
>>> ig = ig_service.create_session()
>>> ig
# Out:
# {'accountType': 'SPREADBET',
#  'accountInfo': {'balance': 1028.24,
#   'deposit': 385.09,
#   'profitLoss': -38.55,
#   'available': 604.6},
#  'currencyIsoCode': 'GBP',
#  'currencySymbol': '£',
#  'currentAccountId': 'Z550FI',
#  'lightstreamerEndpoint': 'https://demo-apd.marketdatasystems.com',
#  'accounts': [{'accountId': 'Z550FH',
#    'accountName': 'CFD',
#    'preferred': False,
#    'accountType': 'CFD'},
#   {'accountId': 'Z550FI',
#    'accountName': 'Spread bet',
#    'preferred': True,
#    'accountType': 'SPREADBET'}],
#  'clientId': '103631951',
#  'timezoneOffset': 1,
#  'hasActiveDemoAccounts': True,
#  'hasActiveLiveAccounts': True,
#  'trailingStopsEnabled': False,
#  'reroutingEnvironment': None,
#  'dealingEnabled': True}

# %%
>>> results = ig_service.search_markets("oil")
>>> results
# Out:
#                     epic                                     instrumentName  \
# 0    EC.D.OILFP.DAILY.IP  Amundi STOXX Euro 600 Engy ESG Scrnd UCITS ETF...
# 1      EC.D.OILFP.JUN.IP  Amundi STOXX Euro 600 Engy ESG Scrnd UCITS ETF...
# 2      EC.D.OILFP.SEP.IP  Amundi STOXX Euro 600 Engy ESG Scrnd UCITS ETF...
# 3      EC.D.OILFP.DEC.IP  Amundi STOXX Euro 600 Engy ESG Scrnd UCITS ETF...
# 4         CC.D.CL.USS.IP                                     Oil - US Crude
# 5      EN.D.CL.Month3.IP                                     Oil - US Crude
# 6      EN.D.CL.Month2.IP                                     Oil - US Crude
# 7     EN.D.LCO.Month2.IP                                  Oil - Brent Crude
# 8     EN.D.LCO.Month4.IP                                  Oil - Brent Crude
# 9        CC.D.LCO.USS.IP                                  Oil - Brent Crude
# 10     EN.D.HO.Month1.IP                                        Heating Oil
# 11     EN.D.HO.Month2.IP                                        Heating Oil
# 12        CC.D.HO.USS.IP                                        Heating Oil
# 13   ED.D.O2CGY.DAILY.IP                                         CAT Oil AG
# 14     ED.D.O2CGY.JUN.IP                                         CAT Oil AG
# 15     ED.D.O2CGY.SEP.IP                                         CAT Oil AG
# 16     ED.D.O2CGY.DEC.IP                                         CAT Oil AG
# 17      CC.D.FCPO.USS.IP                                     Crude Palm Oil
# 18     CO.D.BO.Month3.IP                                        Soybean Oil
# 19     KC.D.GOO.DAILY.IP                                      Baron Oil PLC
# 20       KC.D.GOO.JUN.IP                                      Baron Oil PLC
# 21       KC.D.GOO.SEP.IP                                      Baron Oil PLC
# 22       KC.D.GOO.DEC.IP                                      Baron Oil PLC
# 23     KC.D.JKX.DAILY.IP                                  JKX Oil & Gas PLC
# 24       KC.D.JKX.JUN.IP                                  JKX Oil & Gas PLC
# 25       KC.D.JKX.SEP.IP                                  JKX Oil & Gas PLC
# 26       KC.D.JKX.DEC.IP                                  JKX Oil & Gas PLC
# 27   SE.D.MVOUS.DAILY.IP                                       MV Oil Trust
# 28     SE.D.MVOUS.JUN.IP                                       MV Oil Trust
# 29     SE.D.MVOUS.SEP.IP                                       MV Oil Trust
# 30     SE.D.MVOUS.DEC.IP                                       MV Oil Trust
# 31   EB.D.NES1V.DAILY.IP                                      Neste Oil OYJ
# 32     EB.D.NES1V.JUN.IP                                      Neste Oil OYJ
# 33     EB.D.NES1V.SEP.IP                                      Neste Oil OYJ
# 34     EB.D.NES1V.DEC.IP                                      Neste Oil OYJ
# 35  EH.D.TETYSS.DAILY.IP                               Tethys Oil AB (publ)
# 36    EH.D.TETYSS.JUN.IP                               Tethys Oil AB (publ)
# 37    EH.D.TETYSS.SEP.IP                               Tethys Oil AB (publ)
# 38    EH.D.TETYSS.DEC.IP                               Tethys Oil AB (publ)
# 39     KA.D.TLW.DAILY.IP                                     Tullow Oil PLC
# 40       KA.D.TLW.JUN.IP                                     Tullow Oil PLC
# 41       KA.D.TLW.SEP.IP                                     Tullow Oil PLC
# 42       KA.D.TLW.DEC.IP                                     Tullow Oil PLC
# 43   EE.D.TLWID.DAILY.IP                   Tullow Oil PLC (Euronext Dublin)
# 44     EE.D.TLWID.JUN.IP                   Tullow Oil PLC (Euronext Dublin)
# 45     EE.D.TLWID.SEP.IP                   Tullow Oil PLC (Euronext Dublin)
# 46     EE.D.TLWID.DEC.IP                   Tullow Oil PLC (Euronext Dublin)
# 47    UA.D.ATPG.DAILY.IP                                 ATP Oil & Gas Corp
# 48      UA.D.ATPG.JUN.IP                                 ATP Oil & Gas Corp
# 49      UA.D.ATPG.SEP.IP                                 ATP Oil & Gas Corp
#
#    instrumentType  expiry     high      low  percentageChange  netChange  \
# 0          SHARES     DFB      NaN      NaN             -0.00       0.00
# 1          SHARES  JUN-24      NaN      NaN             -0.00       0.00
# 2          SHARES  SEP-24      NaN      NaN             -0.00       0.00
# 3          SHARES  DEC-24      NaN      NaN             -0.01       0.00
# 4     COMMODITIES     DFB   7757.4   7679.5             -0.65     -50.30
# 5     COMMODITIES  JUL-24   7761.5   7680.5             -0.64     -50.00
# 6     COMMODITIES  AUG-24   7719.5   7643.0             -0.60     -46.00
# 7     COMMODITIES  JUL-24   8193.5   8118.0             -0.53     -43.50
# 8     COMMODITIES  AUG-24   8166.5   8095.5             -0.50     -41.00
# 9     COMMODITIES     DFB   8171.2   8101.6             -0.51     -41.80
# 10    COMMODITIES  JUN-24  24340.0  24143.0             -0.35     -85.00
# 11    COMMODITIES  JUL-24  24484.0  24290.0             -0.33     -80.00
# 12    COMMODITIES     DFB  24445.0  24262.0             -0.33     -80.00
# 13         SHARES     DFB      NaN      NaN             -0.00       0.00
# 14         SHARES  JUN-24    220.8    211.2             -0.00       0.00
# 15         SHARES  SEP-24      NaN      NaN             -0.00       0.00
# 16         SHARES  DEC-24      NaN      NaN             -0.00       0.00
# 17    COMMODITIES     DFB   3912.7   3866.6              0.66      25.50
# 18    COMMODITIES  JUL-24   4595.5   4556.5             -0.22     -10.00
# 19         SHARES     DFB      NaN      NaN              0.00       0.00
# 20         SHARES  JUN-24      NaN      NaN              0.05       0.00
# 21         SHARES  SEP-24      NaN      NaN              0.01       0.00
# 22         SHARES  DEC-24      NaN      NaN              0.04       0.00
# 23         SHARES     DFB      NaN      NaN              0.00       0.00
# 24         SHARES  JUN-24      NaN      NaN             -0.00       0.00
# 25         SHARES  SEP-24      NaN      NaN              0.00       0.00
# 26         SHARES  DEC-24      NaN      NaN             -0.00       0.00
# 27         SHARES     DFB      NaN      NaN             -1.17     -11.00
# 28         SHARES  JUN-24      NaN      NaN             -1.15     -10.90
# 29         SHARES  SEP-24      NaN      NaN             -1.14     -11.00
# 30         SHARES  DEC-24      NaN      NaN             -1.13     -11.00
# 31         SHARES     DFB      NaN      NaN              1.80      35.50
# 32         SHARES  JUN-24      NaN      NaN              1.80      35.50
# 33         SHARES  SEP-24      NaN      NaN              1.78      35.50
# 34         SHARES  DEC-24      NaN      NaN              1.76      35.50
# 35         SHARES     DFB      NaN      NaN              2.26      75.00
# 36         SHARES  JUN-24      NaN      NaN              2.25      75.00
# 37         SHARES  SEP-24      NaN      NaN              2.23      75.00
# 38         SHARES  DEC-24      NaN      NaN              2.20      75.00
# 39         SHARES     DFB      NaN      NaN             -0.03      -0.01
# 40         SHARES  JUN-24      NaN      NaN             -0.03      -0.01
# 41         SHARES  SEP-24      NaN      NaN             -0.03      -0.01
# 42         SHARES  DEC-24      NaN      NaN             -0.03      -0.01
# 43         SHARES     DFB      NaN      NaN              0.00       0.00
# 44         SHARES  JUN-24      NaN      NaN             -0.00       0.00
# 45         SHARES  SEP-24      NaN      NaN              0.00       0.00
# 46         SHARES  DEC-24      NaN      NaN             -0.00       0.00
# 47         SHARES     DFB      NaN      NaN              0.00       0.00
# 48         SHARES  JUN-24      NaN      NaN              0.00       0.00
# 49         SHARES  SEP-24      NaN      NaN              0.00       0.00
#
#    updateTime updateTimeUTC         bid       offer  delayTime  \
# 0    22:54:08      21:54:08   5977.0000   6007.0000          0
# 1    01:30:04      00:30:04   5990.0000   6032.0000          0
# 2    01:30:04      00:30:04   6050.0000   6105.0000          0
# 3    01:30:04      00:30:04   6107.0000   6181.0000          0
# 4    04:29:10      03:29:10   7700.3000   7703.1000          0
# 5    04:29:10      03:29:10   7701.5000   7707.5000          0
# 6    04:29:10      03:29:10   7663.5000   7669.5000          0
# 7    04:29:10      03:29:10   8141.5000   8147.5000          0
# 8    04:29:10      03:29:10   8116.5000   8122.5000          0
# 9    04:29:10      03:29:10   8123.6000   8126.4000          0
# 10   04:29:15      03:29:15  24222.0000  24252.0000          0
# 11   04:29:15      03:29:15  24368.0000  24398.0000          0
# 12   04:29:14      03:29:14  24341.0000  24361.0000          0
# 13   16:30:00      15:30:00    223.4000    224.6000          0
# 14   16:30:00      15:30:00    217.2000    218.8000          0
# 15   16:30:00      15:30:00    224.3000    225.8000          0
# 16   16:30:00      15:30:00    226.4000    228.4000          0
# 17   04:29:17      03:29:17   3896.8000   3908.8000          0
# 18   04:29:07      03:29:07   4570.0000   4580.0000          0
# 19   22:54:09      21:54:09      0.0648      0.0652          0
# 20   22:54:09      21:54:09      0.0649      0.0657          0
# 21   22:54:09      21:54:09      0.0657      0.0667          0
# 22   22:54:09      21:54:09      0.0666      0.0677          0
# 23   16:30:00      15:30:00     40.6100     40.8900          0
# 24   04:00:00      03:00:00     40.6700     41.1600          0
# 25   04:00:00      03:00:00     41.2100     41.7900          0
# 26   04:00:00      03:00:00     41.7200     42.4400          0
# 27   22:54:08      21:54:08    930.6000    933.4000          0
# 28   00:00:00      23:00:00    932.7000    939.2000          0
# 29   00:00:00      23:00:00    945.4000    954.0000          0
# 30   00:00:00      23:00:00    957.7000    969.2000          0
# 31   16:30:20      15:30:20   2001.0000   2005.0000          0
# 32   04:00:00      03:00:00   2002.3000   2016.4000          0
# 33   03:59:59      02:59:59   2022.5000   2040.8000          0
# 34   03:59:59      02:59:59   2041.6000   2066.2000          0
# 35   16:29:44      15:29:44   3386.5000   3403.5000          0
# 36   03:59:59      02:59:59   3393.6000   3417.4000          0
# 37   03:59:59      02:59:59   3426.7000   3457.7000          0
# 38   04:00:00      03:00:00   3458.0000   3499.8000          0
# 39   22:54:09      21:54:09     35.2300     35.4700          0
# 40   03:55:01      02:55:01     35.2800     35.7100          0
# 41   03:55:01      02:55:01     35.7500     36.2500          0
# 42   03:55:01      02:55:01     36.1900     36.8200          0
# 43   16:30:00      15:30:00     54.0100     54.2900          0
# 44   04:00:00      03:00:00     54.1300     54.5100          0
# 45   04:00:00      03:00:00     54.6800     55.1700          0
# 46   04:00:00      03:00:00     55.1900     55.8600          0
# 47   21:00:00      20:00:00      0.5125      0.5125          0
# 48   21:00:00      20:00:00      0.5147      0.5147          0
# 49   04:00:00      03:00:00      0.5222      0.5222          0
#
#     streamingPricesAvailable marketStatus  scalingFactor
# 0                      False   EDITS_ONLY              1
# 1                      False   EDITS_ONLY              1
# 2                      False   EDITS_ONLY              1
# 3                      False   EDITS_ONLY              1
# 4                       True    TRADEABLE              1
# 5                       True    TRADEABLE              1
# 6                       True    TRADEABLE              1
# 7                       True    TRADEABLE              1
# 8                       True    TRADEABLE              1
# 9                       True    TRADEABLE              1
# 10                      True    TRADEABLE              1
# 11                      True    TRADEABLE              1
# 12                      True    TRADEABLE              1
# 13                     False       CLOSED              1
# 14                     False       CLOSED              1
# 15                     False       CLOSED              1
# 16                     False       CLOSED              1
# 17                      True    TRADEABLE              1
# 18                      True    TRADEABLE              1
# 19                     False   EDITS_ONLY              1
# 20                     False   EDITS_ONLY              1
# 21                     False   EDITS_ONLY              1
# 22                     False   EDITS_ONLY              1
# 23                     False       CLOSED              1
# 24                     False       CLOSED              1
# 25                     False       CLOSED              1
# 26                     False       CLOSED              1
# 27                     False   EDITS_ONLY              1
# 28                     False   EDITS_ONLY              1
# 29                     False   EDITS_ONLY              1
# 30                     False   EDITS_ONLY              1
# 31                     False   EDITS_ONLY              1
# 32                     False   EDITS_ONLY              1
# 33                     False   EDITS_ONLY              1
# 34                     False   EDITS_ONLY              1
# 35                     False   EDITS_ONLY              1
# 36                     False   EDITS_ONLY              1
# 37                     False   EDITS_ONLY              1
# 38                     False   EDITS_ONLY              1
# 39                     False   EDITS_ONLY              1
# 40                     False   EDITS_ONLY              1
# 41                     False   EDITS_ONLY              1
# 42                     False   EDITS_ONLY              1
# 43                     False       CLOSED              1
# 44                     False       CLOSED              1
# 45                     False       CLOSED              1
# 46                     False       CLOSED              1
# 47                     False       CLOSED              1
# 48                     False       CLOSED              1
# 49                     False       CLOSED              1

# %%
>>> market = ig_service.fetch_market_by_epic('CC.D.CL.USS.IP')
>>> market
# Out:
# Munch({'instrument': Munch({'epic': 'CC.D.CL.USS.IP', 'expiry': 'DFB', 'name': 'Oil - US Crude', 'forceOpenAllowed': True, 'stopsLimitsAllowed': True, 'lotSize': 1.0, 'unit': 'AMOUNT', 'type': 'COMMODITIES', 'controlledRiskAllowed': True, 'streamingPricesAvailable': True, 'marketId': 'CL', 'currencies': [Munch({'code': 'GBP', 'symbol': '£', 'baseExchangeRate': 1.0, 'exchangeRate': 1.0, 'isDefault': True}), Munch({'code': 'EUR', 'symbol': 'E', 'baseExchangeRate': 1.175135, 'exchangeRate': 0.9, 'isDefault': False}), Munch({'code': 'USD', 'symbol': '$', 'baseExchangeRate': 1.272573, 'exchangeRate': 0.66, 'isDefault': False})], 'sprintMarketsMinimumExpiryTime': None, 'sprintMarketsMaximumExpiryTime': None, 'marginDepositBands': [Munch({'min': 0, 'max': 700, 'margin': 10, 'currency': 'USD'}), Munch({'min': 700, 'max': 1400, 'margin': 10, 'currency': 'USD'}), Munch({'min': 1400, 'max': 2100, 'margin': 10, 'currency': 'USD'}), Munch({'min': 2100, 'max': None, 'margin': 15, 'currency': 'USD'})], 'marginFactor': 10, 'marginFactorUnit': 'PERCENTAGE', 'slippageFactor': Munch({'unit': 'pct', 'value': 100.0}), 'limitedRiskPremium': Munch({'value': 6, 'unit': 'POINTS'}), 'openingHours': None, 'expiryDetails': Munch({'lastDealingDate': '2029-04-06T22:59'}), 'rolloverDetails': None, 'newsCode': 'CRU', 'chartCode': None, 'country': None, 'valueOfOnePip': None, 'onePipMeans': None, 'contractSize': None, 'specialInfo': ['DEFAULT KNOCK OUT LEVEL DISTANCE', 'MIN KNOCK OUT LEVEL DISTANCE', 'MAX KNOCK OUT LEVEL DISTANCE']}), 'dealingRules': Munch({'minStepDistance': Munch({'unit': 'POINTS', 'value': 10.0}), 'minDealSize': Munch({'unit': 'POINTS', 'value': 0.5}), 'minControlledRiskStopDistance': Munch({'unit': 'POINTS', 'value': 10.0}), 'minNormalStopOrLimitDistance': Munch({'unit': 'POINTS', 'value': 6.0}), 'maxStopOrLimitDistance': Munch({'unit': 'POINTS', 'value': 10000.0}), 'controlledRiskSpacing': Munch({'unit': 'POINTS', 'value': 20.0}), 'marketOrderPreference': 'AVAILABLE_DEFAULT_OFF', 'trailingStopsPreference': 'AVAILABLE'}), 'snapshot': Munch({'marketStatus': 'TRADEABLE', 'netChange': -50.3, 'percentageChange': -0.65, 'updateTime': '03:29:10', 'delayTime': 0, 'bid': 7700.3, 'offer': 7703.1, 'high': 7757.4, 'low': 7679.5, 'binaryOdds': None, 'decimalPlacesFactor': 1, 'scalingFactor': 1, 'controlledRiskExtraSpread': 4})})

# %%
>>> result = ig_service.fetch_historical_prices_by_epic(epic='CC.D.CL.USS.IP')
>>> result['prices']
# Out:
#                         bid                             ask                  \
#                        Open    High     Low   Close    Open    High     Low
# DateTime
# 2024-05-23 04:20:00  7703.3  7703.3  7702.3  7703.3  7706.1  7707.1  7705.1
# 2024-05-23 04:21:00  7702.3  7703.3  7701.3  7702.3  7705.1  7706.1  7704.1
# 2024-05-23 04:22:00  7703.3  7704.3  7703.3  7703.3  7705.1  7707.1  7705.1
# 2024-05-23 04:23:00  7704.3  7704.3  7703.3  7703.3  7707.1  7707.1  7706.1
# 2024-05-23 04:24:00  7702.3  7703.3  7701.3  7703.3  7705.1  7706.1  7704.1
# 2024-05-23 04:25:00  7702.4  7703.3  7702.3  7702.3  7705.2  7706.1  7705.1
# 2024-05-23 04:26:00  7702.4  7702.4  7701.3  7701.3  7705.1  7706.1  7704.1
# 2024-05-23 04:27:00  7702.3  7702.3  7700.3  7701.3  7705.1  7705.1  7703.1
# 2024-05-23 04:28:00  7702.3  7702.3  7699.9  7700.3  7705.1  7705.1  7703.1
# 2024-05-23 04:29:00     NaN     NaN     NaN     NaN  7704.1  7704.1  7703.1
#
#                             last
#                       Close Open High Low Close Volume
# DateTime
# 2024-05-23 04:20:00  7706.1  NaN  NaN NaN   NaN     27
# 2024-05-23 04:21:00  7706.1  NaN  NaN NaN   NaN     41
# 2024-05-23 04:22:00  7706.1  NaN  NaN NaN   NaN     45
# 2024-05-23 04:23:00  7706.1  NaN  NaN NaN   NaN     29
# 2024-05-23 04:24:00  7706.1  NaN  NaN NaN   NaN     42
# 2024-05-23 04:25:00  7706.1  NaN  NaN NaN   NaN     19
# 2024-05-23 04:26:00  7704.1  NaN  NaN NaN   NaN     26
# 2024-05-23 04:27:00  7704.1  NaN  NaN NaN   NaN     33
# 2024-05-23 04:28:00  7703.1  NaN  NaN NaN   NaN     78
# 2024-05-23 04:29:00  7703.1  NaN  NaN NaN   NaN      0

# %%
>>> resp = ig_service.create_open_position(
        currency_code='GBP',
        direction='SELL',
        epic='CC.D.CL.USS.IP',
        order_type='MARKET',
        expiry='DFB',
        force_open='false',
        guaranteed_stop='false',
        size=0.5, level=None,
        limit_distance=None,
        limit_level=None,
        quote_id=None,
        stop_level=None,
        stop_distance=None,
        trailing_stop=None,
        trailing_stop_increment=None)
>>> resp
# Out:
# {'date': '2024-05-23T03:29:23.501',
#  'status': 'CLOSED',
#  'reason': 'SUCCESS',
#  'dealStatus': 'ACCEPTED',
#  'epic': 'CC.D.CL.USS.IP',
#  'expiry': 'DFB',
#  'dealReference': 'ERP6SVYGYGYTYM9',
#  'dealId': 'DIAAAAP22UN94BC',
#  'affectedDeals': [{'dealId': 'DIAAAAP22UN94BC', 'status': 'FULLY_CLOSED'}],
#  'level': 7700.3,
#  'size': 0.5,
#  'direction': 'SELL',
#  'stopLevel': None,
#  'limitLevel': None,
#  'stopDistance': None,
#  'limitDistance': None,
#  'guaranteedStop': False,
#  'trailingStop': False,
#  'profit': -38.55,
#  'profitCurrency': 'GBP'}

# %%
from_date = datetime(2024, 1, 5)
activities = ig_service.fetch_account_activity(from_date=from_date)
activities
# Out:
#                    date                  epic period           dealId  \
# 0   2024-05-22T18:15:07        CC.D.CL.USS.IP    DFB  DIAAAAP22WWY6AZ
# 1   2024-05-22T17:47:01        CC.D.CL.USS.IP    DFB  DIAAAAP22UN94BC
# 2   2024-05-22T17:27:59        CC.D.CL.USS.IP    DFB  DIAAAAP22SNU7AE
# 3   2024-05-16T13:18:03        CC.D.CL.USS.IP    DFB  DIAAAAPZK27ULAC
# 4   2024-05-15T23:51:11        CC.D.CL.USS.IP    DFB  DIAAAAPZK2Y4NAG
# 5   2024-05-08T23:49:43  CS.D.GBPCAD.TODAY.IP    DFB  DIAAAAPXUM3E5AB
# 6   2024-05-08T23:10:16        CC.D.CL.USS.IP    DFB  DIAAAAPXULJC4AE
# 7   2024-05-08T23:10:01        CC.D.CL.USS.IP    DFB  DIAAAAPXULPZ9A2
# 8   2024-04-05T13:47:13        CC.D.CL.USS.IP    DFB  DIAAAAPPX4V9WAM
# 9   2024-04-05T12:59:32        CC.D.CL.USS.IP    DFB  DIAAAAPPX5HR4A2
# 10  2024-04-03T16:46:52        CC.D.CL.USS.IP    DFB  DIAAAAPN9Z2WWAM
# 11  2024-04-03T14:30:40        CC.D.CL.USS.IP    DFB  DIAAAAPN92FC8AU
# 12  2024-03-27T18:34:43        CC.D.CL.USS.IP    DFB  DIAAAAPMKTPWGA7
# 13  2024-03-27T17:02:11        CC.D.CL.USS.IP    DFB  DIAAAAPMKT26UAS
# 14  2024-03-27T14:33:50        CC.D.CL.USS.IP    DFB  DIAAAAPMKJLREA7
# 15  2024-03-27T14:30:34        CC.D.CL.USS.IP    DFB  DIAAAAPMKJLQ7A7
# 16  2024-03-22T13:38:17        CC.D.CL.USS.IP    DFB  DIAAAAPLK48VEAT
# 17  2024-03-22T13:00:27        CC.D.CL.USS.IP    DFB  DIAAAAPLK5WCYBC
# 18  2024-03-22T12:56:32  CS.D.GBPCAD.TODAY.IP    DFB  DIAAAAPLK3W5CAT
# 19  2024-03-22T12:30:10  CS.D.GBPCAD.TODAY.IP    DFB  DIAAAAPLK25EQA6
# 20  2024-03-20T10:29:26  CS.D.GBPCAD.TODAY.IP    DFB  DIAAAAPK4XSXJBC
# 21  2024-03-20T07:00:36  CS.D.GBPCAD.TODAY.IP    DFB  DIAAAAPK4JM5RA2
# 22  2024-03-18T07:18:10        CC.D.CL.USS.IP    DFB  DIAAAAPJ6M626AT
# 23  2024-03-18T02:15:33        CC.D.CL.USS.IP    DFB  DIAAAAPJ6SP5WA4
# 24  2024-03-18T01:00:17        CC.D.CL.USS.IP    DFB  DIAAAAPJ6MZ78A5
# 25  2024-03-15T15:12:27        CC.D.CL.USS.IP    DFB  DIAAAAPJ46NUWAT
# 26  2024-03-15T15:03:32        CC.D.CL.USS.IP    DFB  DIAAAAPJ5DHG3A2
# 27  2024-03-15T14:11:00        CC.D.CL.USS.IP    DFB  DIAAAAPJ4758TA8
# 28  2024-03-15T14:00:10        CC.D.CL.USS.IP    DFB  DIAAAAPJ46DYFAP
#
#            channel                 type    status  \
# 0   PUBLIC_WEB_API             POSITION  ACCEPTED
# 1   PUBLIC_WEB_API             POSITION  ACCEPTED
# 2   PUBLIC_WEB_API             POSITION  ACCEPTED
# 3           SYSTEM             POSITION  ACCEPTED
# 4              WEB             POSITION  ACCEPTED
# 5              WEB             POSITION  REJECTED
# 6              WEB             POSITION  ACCEPTED
# 7              WEB             POSITION  ACCEPTED
# 8           SYSTEM             POSITION  ACCEPTED
# 9           SYSTEM             POSITION  ACCEPTED
# 10          SYSTEM             POSITION  ACCEPTED
# 11             WEB             POSITION  ACCEPTED
# 12          SYSTEM             POSITION  ACCEPTED
# 13             WEB             POSITION  ACCEPTED
# 14          SYSTEM             POSITION  ACCEPTED
# 15             WEB             POSITION  ACCEPTED
# 16          SYSTEM             POSITION  ACCEPTED
# 17             WEB             POSITION  ACCEPTED
# 18          SYSTEM             POSITION  ACCEPTED
# 19             WEB             POSITION  ACCEPTED
# 20             WEB             POSITION  ACCEPTED
# 21             WEB             POSITION  ACCEPTED
# 22          SYSTEM             POSITION  ACCEPTED
# 23          SYSTEM  EDIT_STOP_AND_LIMIT  ACCEPTED
# 24             WEB             POSITION  ACCEPTED
# 25          SYSTEM             POSITION  ACCEPTED
# 26          SYSTEM  EDIT_STOP_AND_LIMIT  ACCEPTED
# 27          SYSTEM  EDIT_STOP_AND_LIMIT  ACCEPTED
# 28             WEB             POSITION  ACCEPTED
#
#                      description details
# 0    Position/s closed: 22SNU7AE    None
# 1      Position opened: 22UN94BC    None
# 2      Position opened: 22SNU7AE    None
# 3    Position/s closed: ZK2Y4NAG    None
# 4      Position opened: ZK2Y4NAG    None
# 5   Rejected: Insufficient funds    None
# 6    Position/s closed: XULPZ9A2    None
# 7      Position opened: XULPZ9A2    None
# 8    Position/s closed: PX5HR4A2    None
# 9      Position opened: PX5HR4A2    None
# 10   Position/s closed: N92FC8AU    None
# 11     Position opened: N92FC8AU    None
# 12   Position/s closed: MKT26UAS    None
# 13     Position opened: MKT26UAS    None
# 14   Position/s closed: MKJLQ7A7    None
# 15     Position opened: MKJLQ7A7    None
# 16   Position/s closed: LK5WCYBC    None
# 17     Position opened: LK5WCYBC    None
# 18   Position/s closed: LK25EQA6    None
# 19     Position opened: LK25EQA6    None
# 20   Position/s closed: K4JM5RA2    None
# 21     Position opened: K4JM5RA2    None
# 22   Position/s closed: J6MZ78A5    None
# 23  Stop/Limit amended: J6MZ78A5    None
# 24     Position opened: J6MZ78A5    None
# 25   Position/s closed: J46DYFAP    None
# 26  Stop/Limit amended: J46DYFAP    None
# 27  Stop/Limit amended: J46DYFAP    None
# 28     Position opened: J46DYFAP    None

# %%
>>> from trading_ig import IGService, IGStreamService
>>> from trading_ig.config import config
>>> from trading_ig.lightstreamer import Subscription

# %%
>>> def on_update(item):
>>>     print("{UPDATE_TIME:<8} {stock_name:<19} Bid {BID:>5} Ask {OFFER:>5}".format(stock_name=item["name"], **item["values"]))

# %%
>>> ig_service = IGService(config.username, config.password, config.api_key, config.acc_type, acc_number=config.acc_number)
>>> ig_stream_service = IGStreamService(ig_service)
>>> ig_stream_service.create_session()
>>> sub = Subscription(mode="MERGE", items=["L1:CC.D.CL.USS.IP"], fields=["UPDATE_TIME", "BID", "OFFER"])
>>> sub.addlistener(on_update)
>>> ig_stream_service.ls_client.subscribe(sub)
>>> ig_stream_service.disconnect()
# Out:
# 18:51:00 L1:CC.D.CL.USS.IP   Bid 7768.6 Ask 7771.4
# DISCONNECTED FROM LIGHTSTREAMER
