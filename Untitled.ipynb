# %%
import numpy as np
import pandas as pd
import requests
import xlsxwriter
import math
import datetime
import socket

# %%
>>> from trading_ig.rest import IGService
>>> from trading_ig.config import config
>>> ig_service = IGService(config.username, config.password, config.api_key)
>>> ig = ig_service.create_session()
>>> ig
# Out:
# {'accountType': 'SPREADBET',
#  'accountInfo': {'balance': 5051.51,
#   'deposit': 442.29,
#   'profitLoss': 639.6,
#   'available': 5248.82},
#  'currencyIsoCode': 'GBP',
#  'currencySymbol': '£',
#  'currentAccountId': 'Z550FI',
#  'lightstreamerEndpoint': 'https://demo-apd.marketdatasystems.com',
#  'accounts': [{'accountId': 'Z550FH',
#    'accountName': 'CFD',
#    'preferred': False,
#    'accountType': 'CFD'},
#   {'accountId': 'Z550FI',
#    'accountName': 'Spread bet',
#    'preferred': True,
#    'accountType': 'SPREADBET'}],
#  'clientId': '103631951',
#  'timezoneOffset': 1,
#  'hasActiveDemoAccounts': True,
#  'hasActiveLiveAccounts': True,
#  'trailingStopsEnabled': False,
#  'reroutingEnvironment': None,
#  'dealingEnabled': True}

# %%
>>> results = ig_service.search_markets("oil")
>>> results
# Out:
#                     epic                                  instrumentName  \
# 0    EC.D.OILFP.DAILY.IP  Amundi STOXX Euro Engy ESG Scrnd UCITS ETF Acc
# 1      EC.D.OILFP.SEP.IP  Amundi STOXX Euro Engy ESG Scrnd UCITS ETF Acc
# 2      EC.D.OILFP.DEC.IP  Amundi STOXX Euro Engy ESG Scrnd UCITS ETF Acc
# 3      EC.D.OILFP.MAR.IP  Amundi STOXX Euro Engy ESG Scrnd UCITS ETF Acc
# 4         CC.D.CL.USS.IP                                  Oil - US Crude
# 5      EN.D.CL.Month3.IP                                  Oil - US Crude
# 6      EN.D.CL.Month2.IP                                  Oil - US Crude
# 7      EN.D.CL.Month1.IP                                  Oil - US Crude
# 8     EN.D.LCO.Month3.IP                               Oil - Brent Crude
# 9     EN.D.LCO.Month5.IP                               Oil - Brent Crude
# 10    EN.D.LCO.Month6.IP                               Oil - Brent Crude
# 11       CC.D.LCO.USS.IP                               Oil - Brent Crude
# 12     EN.D.HO.Month1.IP                                     Heating Oil
# 13     EN.D.HO.Month2.IP                                     Heating Oil
# 14        CC.D.HO.USS.IP                                     Heating Oil
# 15   ED.D.O2CGY.DAILY.IP                                      CAT Oil AG
# 16     ED.D.O2CGY.SEP.IP                                      CAT Oil AG
# 17     ED.D.O2CGY.DEC.IP                                      CAT Oil AG
# 18     ED.D.O2CGY.MAR.IP                                      CAT Oil AG
# 19      CC.D.FCPO.USS.IP                                  Crude Palm Oil
# 20     CO.D.BO.Month3.IP                                     Soybean Oil
# 21     KC.D.GOO.DAILY.IP                                   Baron Oil PLC
# 22       KC.D.GOO.SEP.IP                                   Baron Oil PLC
# 23       KC.D.GOO.DEC.IP                                   Baron Oil PLC
# 24       KC.D.GOO.MAR.IP                                   Baron Oil PLC
# 25     KC.D.JKX.DAILY.IP                               JKX Oil & Gas PLC
# 26       KC.D.JKX.SEP.IP                               JKX Oil & Gas PLC
# 27       KC.D.JKX.DEC.IP                               JKX Oil & Gas PLC
# 28       KC.D.JKX.MAR.IP                               JKX Oil & Gas PLC
# 29   SE.D.MVOUS.DAILY.IP                                    MV Oil Trust
# 30     SE.D.MVOUS.SEP.IP                                    MV Oil Trust
# 31     SE.D.MVOUS.DEC.IP                                    MV Oil Trust
# 32     SE.D.MVOUS.MAR.IP                                    MV Oil Trust
# 33   EB.D.NES1V.DAILY.IP                                   Neste Oil OYJ
# 34     EB.D.NES1V.SEP.IP                                   Neste Oil OYJ
# 35     EB.D.NES1V.DEC.IP                                   Neste Oil OYJ
# 36     EB.D.NES1V.MAR.IP                                   Neste Oil OYJ
# 37  KC.D.ENEGLN.DAILY.IP                              Nu-Oil And Gas PLC
# 38    KC.D.ENEGLN.SEP.IP                              Nu-Oil And Gas PLC
# 39    KC.D.ENEGLN.DEC.IP                              Nu-Oil And Gas PLC
# 40    KC.D.ENEGLN.MAR.IP                              Nu-Oil And Gas PLC
# 41  EH.D.TETYSS.DAILY.IP                            Tethys Oil AB (publ)
# 42    EH.D.TETYSS.SEP.IP                            Tethys Oil AB (publ)
# 43    EH.D.TETYSS.DEC.IP                            Tethys Oil AB (publ)
# 44    EH.D.TETYSS.MAR.IP                            Tethys Oil AB (publ)
# 45     KA.D.TLW.DAILY.IP                                  Tullow Oil PLC
# 46       KA.D.TLW.SEP.IP                                  Tullow Oil PLC
# 47       KA.D.TLW.DEC.IP                                  Tullow Oil PLC
# 48       KA.D.TLW.MAR.IP                                  Tullow Oil PLC
# 49   EE.D.TLWID.DAILY.IP                Tullow Oil PLC (Euronext Dublin)
#
#    instrumentType  expiry        high         low  percentageChange  \
# 0          SHARES     DFB   5663.0000   5586.0000              0.04
# 1          SHARES  SEP-23   5673.0000   5585.0000              0.04
# 2          SHARES  DEC-23   5738.0000   5637.0000              0.04
# 3          SHARES  MAR-24   5806.0000   5687.0000              0.04
# 4     COMMODITIES     DFB   8874.2000   8668.1000              1.97
# 5     COMMODITIES  OCT-23   8932.5000   8714.5000              2.05
# 6     COMMODITIES  NOV-23   8859.5000   8651.5000              1.98
# 7     COMMODITIES  DEC-23   8776.0000   8580.0000              1.84
# 8     COMMODITIES  NOV-23   9240.5000   9048.5000              1.70
# 9     COMMODITIES  DEC-23   9167.5000   8988.5000              1.59
# 10    COMMODITIES  JAN-24   9083.5000   8917.5000              1.48
# 11    COMMODITIES     DFB   9204.7000   9023.3000              1.63
# 12    COMMODITIES  OCT-23  33941.0000  33103.0000             -1.40
# 13    COMMODITIES  NOV-23  33060.0000  32414.0000             -0.95
# 14    COMMODITIES     DFB  33533.0000  32782.0000             -1.27
# 15         SHARES     DFB         NaN         NaN             -0.00
# 16         SHARES  SEP-23         NaN         NaN             -0.00
# 17         SHARES  DEC-23         NaN         NaN             -0.00
# 18         SHARES  MAR-24         NaN         NaN             -0.00
# 19    COMMODITIES     DFB   3736.8000   3643.1000             -1.45
# 20    COMMODITIES  DEC-23   6076.5000   5945.0000             -1.19
# 21         SHARES     DFB      0.0853      0.0797              0.00
# 22         SHARES  SEP-23      0.0856      0.0796              0.01
# 23         SHARES  DEC-23      0.0869      0.0807              0.04
# 24         SHARES  MAR-24      0.0882      0.0817              0.01
# 25         SHARES     DFB     40.8900     40.6100              0.00
# 26         SHARES  SEP-23     41.0400     40.5500              0.00
# 27         SHARES  DEC-23     41.6700     41.0900              0.01
# 28         SHARES  MAR-24     42.3100     41.6000             -0.00
# 29         SHARES     DFB   1313.0000   1268.9000              1.95
# 30         SHARES  SEP-23   1317.1000   1267.8000              1.95
# 31         SHARES  DEC-23   1337.8000   1285.2000              1.93
# 32         SHARES  MAR-24   1359.3000   1301.9000              1.90
# 33         SHARES     DFB   3606.0000   3433.0000             -2.44
# 34         SHARES  SEP-23   3617.0000   3427.0000             -2.45
# 35         SHARES  DEC-23   3658.0000   3459.0000             -2.42
# 36         SHARES  MAR-24   3701.0000   3490.0000             -2.39
# 37         SHARES     DFB         NaN         NaN              0.00
# 38         SHARES  SEP-23         NaN         NaN              0.00
# 39         SHARES  DEC-23         NaN         NaN              0.03
# 40         SHARES  MAR-24         NaN         NaN              0.00
# 41         SHARES     DFB   5739.0000   5464.0000              2.44
# 42         SHARES  SEP-23   5750.0000   5464.0000              2.44
# 43         SHARES  DEC-23   5815.0000   5515.0000              2.41
# 44         SHARES  MAR-24   5883.0000   5563.0000              2.39
# 45         SHARES     DFB     37.9900     36.3900              1.40
# 46         SHARES  SEP-23     38.1300     36.3400              1.39
# 47         SHARES  DEC-23     38.7100     36.8200              1.38
# 48         SHARES  MAR-24     39.3100     37.2800              1.37
# 49         SHARES     DFB     54.2900     54.0100              0.00
#
#     netChange updateTime updateTimeUTC         bid       offer  delayTime  \
# 0        2.00   16:35:14      15:35:14   5624.0000   5653.0000          0
# 1        2.00   16:35:14      15:35:14   5623.0000   5663.0000          0
# 2        2.00   16:35:14      15:35:14   5676.0000   5728.0000          0
# 3        2.00   16:35:14      15:35:14   5726.0000   5796.0000          0
# 4      171.40   17:15:26      16:15:26   8850.1000   8852.9000          0
# 5      179.00   17:15:24      16:15:24   8904.5000   8910.5000          0
# 6      171.50   17:15:26      16:15:26   8833.0000   8839.0000          0
# 7      158.50   17:15:26      16:15:26   8749.0000   8755.0000          0
# 8      154.50   17:15:26      16:15:26   9216.0000   9222.0000          0
# 9      143.00   17:15:23      16:15:23   9143.5000   9149.5000          0
# 10     132.00   17:15:24      16:15:24   9060.5000   9066.5000          0
# 11     147.40   17:15:27      16:15:27   9183.0000   9185.8000          0
# 12    -471.00   17:15:24      16:15:24  33138.0000  33168.0000          0
# 13    -310.00   17:15:26      16:15:26  32440.0000  32470.0000          0
# 14    -423.00   17:15:24      16:15:24  32813.0000  32833.0000          0
# 15       0.00   16:30:00      15:30:00    223.4400    224.5600          0
# 16       0.00   16:30:00      15:30:00    224.2700    225.8400          0
# 17       0.00   16:30:00      15:30:00    226.3800    228.4200          0
# 18       0.00   16:30:00      15:30:00    228.3700    231.1200          0
# 19     -54.00   16:29:53      15:29:53   3667.8000   3679.8000          0
# 20     -72.00   17:15:25      16:15:25   5983.0000   5993.0000          0
# 21       0.00   17:00:00      16:00:00      0.0822      0.0828          0
# 22       0.00   17:00:00      16:00:00      0.0821      0.0831          0
# 23       0.00   17:00:00      16:00:00      0.0832      0.0844          0
# 24       0.00   17:00:00      16:00:00      0.0842      0.0857          0
# 25       0.00   16:30:00      15:30:00     40.6100     40.8900          0
# 26       0.00   16:30:00      15:30:00     40.5500     41.0400          0
# 27       0.00   16:30:00      15:30:00     41.0900     41.6700          0
# 28       0.00   16:30:00      15:30:00     41.6000     42.3100          0
# 29      25.00   17:15:26      16:15:26   1299.0000   1313.0000          0
# 30      25.00   17:15:26      16:15:26   1297.9000   1317.1000          0
# 31      25.10   17:15:26      16:15:26   1315.9000   1337.8000          0
# 32      25.00   17:15:26      16:15:26   1333.1000   1359.3000          0
# 33     -88.00   16:30:17      15:30:17   3497.0000   3504.0000          0
# 34     -88.00   16:30:17      15:30:17   3491.0000   3515.0000          0
# 35     -88.00   16:30:16      15:30:16   3524.0000   3555.0000          0
# 36     -88.00   16:30:15      15:30:15   3555.0000   3598.0000          0
# 37       0.00   16:30:00      15:30:00      0.0274      0.0276          0
# 38       0.00   16:30:00      15:30:00      0.0274      0.0277          0
# 39       0.00   16:30:00      15:30:00      0.0274      0.0278          0
# 40       0.00   16:30:00      15:30:00      0.0273      0.0277          0
# 41     135.00   16:29:42      15:29:42   5660.0000   5688.0000          0
# 42     135.00   16:29:43      15:29:43   5659.0000   5698.0000          0
# 43     135.00   16:29:44      15:29:44   5711.0000   5763.0000          0
# 44     135.00   16:29:44      15:29:44   5761.0000   5831.0000          0
# 45       0.52   17:00:00      16:00:00     37.5500     37.8100          0
# 46       0.52   17:00:00      16:00:00     37.4900     37.9500          0
# 47       0.52   17:00:00      16:00:00     37.9900     38.5300          0
# 48       0.52   17:00:00      16:00:00     38.4700     39.1300          0
# 49       0.00   16:30:00      15:30:00     54.0100     54.2900          0
#
#     streamingPricesAvailable marketStatus  scalingFactor
# 0                      False   EDITS_ONLY              1
# 1                      False   EDITS_ONLY              1
# 2                      False   EDITS_ONLY              1
# 3                      False   EDITS_ONLY              1
# 4                       True    TRADEABLE              1
# 5                       True    TRADEABLE              1
# 6                       True    TRADEABLE              1
# 7                       True    TRADEABLE              1
# 8                       True    TRADEABLE              1
# 9                       True    TRADEABLE              1
# 10                      True    TRADEABLE              1
# 11                      True    TRADEABLE              1
# 12                      True    TRADEABLE              1
# 13                      True    TRADEABLE              1
# 14                      True    TRADEABLE              1
# 15                     False       CLOSED              1
# 16                     False       CLOSED              1
# 17                     False       CLOSED              1
# 18                     False       CLOSED              1
# 19                      True   EDITS_ONLY              1
# 20                      True    TRADEABLE              1
# 21                     False   EDITS_ONLY              1
# 22                     False   EDITS_ONLY              1
# 23                     False   EDITS_ONLY              1
# 24                     False   EDITS_ONLY              1
# 25                     False       CLOSED              1
# 26                     False       CLOSED              1
# 27                     False       CLOSED              1
# 28                     False       CLOSED              1
# 29                     False    TRADEABLE              1
# 30                     False    TRADEABLE              1
# 31                     False    TRADEABLE              1
# 32                     False    TRADEABLE              1
# 33                     False   EDITS_ONLY              1
# 34                     False   EDITS_ONLY              1
# 35                     False   EDITS_ONLY              1
# 36                     False   EDITS_ONLY              1
# 37                     False       CLOSED              1
# 38                     False       CLOSED              1
# 39                     False       CLOSED              1
# 40                     False       CLOSED              1
# 41                     False   EDITS_ONLY              1
# 42                     False   EDITS_ONLY              1
# 43                     False   EDITS_ONLY              1
# 44                     False   EDITS_ONLY              1
# 45                     False   EDITS_ONLY              1
# 46                     False   EDITS_ONLY              1
# 47                     False   EDITS_ONLY              1
# 48                     False   EDITS_ONLY              1
# 49                     False       CLOSED              1

# %%
>>> market = ig_service.fetch_market_by_epic('CC.D.CL.USS.IP')
>>> market
# Out:
# Munch({'instrument': Munch({'epic': 'CC.D.CL.USS.IP', 'expiry': 'DFB', 'name': 'Oil - US Crude', 'forceOpenAllowed': True, 'stopsLimitsAllowed': True, 'lotSize': 1.0, 'unit': 'AMOUNT', 'type': 'COMMODITIES', 'controlledRiskAllowed': True, 'streamingPricesAvailable': True, 'marketId': 'CL', 'currencies': [Munch({'code': 'GBP', 'symbol': '£', 'baseExchangeRate': 1.0, 'exchangeRate': 1.0, 'isDefault': True}), Munch({'code': 'EUR', 'symbol': 'E', 'baseExchangeRate': 1.163215, 'exchangeRate': 0.9, 'isDefault': False}), Munch({'code': 'USD', 'symbol': '$', 'baseExchangeRate': 1.2486495, 'exchangeRate': 0.66, 'isDefault': False})], 'sprintMarketsMinimumExpiryTime': None, 'sprintMarketsMaximumExpiryTime': None, 'marginDepositBands': [Munch({'min': 0, 'max': 700, 'margin': 10, 'currency': 'USD'}), Munch({'min': 700, 'max': 1400, 'margin': 10, 'currency': 'USD'}), Munch({'min': 1400, 'max': 2100, 'margin': 10, 'currency': 'USD'}), Munch({'min': 2100, 'max': None, 'margin': 15, 'currency': 'USD'})], 'marginFactor': 10, 'marginFactorUnit': 'PERCENTAGE', 'slippageFactor': Munch({'unit': 'pct', 'value': 100.0}), 'limitedRiskPremium': Munch({'value': 6, 'unit': 'POINTS'}), 'openingHours': None, 'expiryDetails': Munch({'lastDealingDate': '2029-04-06T22:59'}), 'rolloverDetails': None, 'newsCode': 'CRU', 'chartCode': None, 'country': None, 'valueOfOnePip': None, 'onePipMeans': None, 'contractSize': None, 'specialInfo': ['DEFAULT KNOCK OUT LEVEL DISTANCE', 'MIN KNOCK OUT LEVEL DISTANCE', 'MAX KNOCK OUT LEVEL DISTANCE']}), 'dealingRules': Munch({'minStepDistance': Munch({'unit': 'POINTS', 'value': 10.0}), 'minDealSize': Munch({'unit': 'POINTS', 'value': 0.5}), 'minControlledRiskStopDistance': Munch({'unit': 'POINTS', 'value': 10.0}), 'minNormalStopOrLimitDistance': Munch({'unit': 'POINTS', 'value': 6.0}), 'maxStopOrLimitDistance': Munch({'unit': 'POINTS', 'value': 10000.0}), 'controlledRiskSpacing': Munch({'unit': 'POINTS', 'value': 20.0}), 'marketOrderPreference': 'AVAILABLE_DEFAULT_OFF', 'trailingStopsPreference': 'AVAILABLE'}), 'snapshot': Munch({'marketStatus': 'TRADEABLE', 'netChange': 168.2, 'percentageChange': 1.94, 'updateTime': '16:15:27', 'delayTime': 0, 'bid': 8846.9, 'offer': 8849.7, 'high': 8874.2, 'low': 8668.1, 'binaryOdds': None, 'decimalPlacesFactor': 1, 'scalingFactor': 1, 'controlledRiskExtraSpread': 4})})

# %%
>>> result = ig_service.fetch_historical_prices_by_epic(epic='CC.D.CL.USS.IP')
>>> result['prices']
# Out:
#                         bid                             ask                  \
#                        Open    High     Low   Close    Open    High     Low
# DateTime
# 2023-09-12 17:06:00  8842.7  8844.5  8838.1  8842.7  8846.5  8847.9  8840.9
# 2023-09-12 17:07:00  8843.1  8844.7  8840.1  8844.7  8845.9  8847.9  8843.5
# 2023-09-12 17:08:00  8844.1  8849.1  8844.1  8844.5  8846.9  8852.5  8846.9
# 2023-09-12 17:09:00  8845.5  8846.3  8843.1  8843.5  8848.8  8849.3  8846.3
# 2023-09-12 17:10:00  8843.9  8846.5  8841.5  8845.5  8846.7  8849.3  8844.3
# 2023-09-12 17:11:00  8846.5  8852.5  8846.1  8846.5  8849.3  8855.3  8849.3
# 2023-09-12 17:12:00  8846.1  8850.5  8846.1  8849.7  8848.9  8853.3  8848.9
# 2023-09-12 17:13:00  8850.7  8851.7  8848.1  8848.5  8853.5  8855.0  8851.3
# 2023-09-12 17:14:00  8848.7  8850.3  8845.7  8848.9  8851.5  8853.7  8848.5
# 2023-09-12 17:15:00  8848.5  8851.7  8846.9  8847.5  8852.3  8854.9  8849.7
#
#                             last
#                       Close Open High Low Close Volume
# DateTime
# 2023-09-12 17:06:00  8845.5  NaN  NaN NaN   NaN    684
# 2023-09-12 17:07:00  8847.5  NaN  NaN NaN   NaN    273
# 2023-09-12 17:08:00  8848.3  NaN  NaN NaN   NaN    999
# 2023-09-12 17:09:00  8847.3  NaN  NaN NaN   NaN    424
# 2023-09-12 17:10:00  8848.3  NaN  NaN NaN   NaN    698
# 2023-09-12 17:11:00  8849.3  NaN  NaN NaN   NaN    430
# 2023-09-12 17:12:00  8852.5  NaN  NaN NaN   NaN    115
# 2023-09-12 17:13:00  8851.3  NaN  NaN NaN   NaN    173
# 2023-09-12 17:14:00  8851.7  NaN  NaN NaN   NaN    178
# 2023-09-12 17:15:00  8850.3  NaN  NaN NaN   NaN    364

# %%
>>> resp = ig_service.create_open_position(
        currency_code='GBP',
        direction='BUY',
        epic='CC.D.CL.USS.IP',
        order_type='MARKET',
        expiry='DFB',
        force_open='false',
        guaranteed_stop='false',
        size=0.5, level=None,
        limit_distance=None,
        limit_level=None,
        quote_id=None,
        stop_level=None,
        stop_distance=None,
        trailing_stop=None,
        trailing_stop_increment=None)
>>> resp
# Out:
# {'date': '2023-07-13T20:56:20.957',
#  'status': 'OPEN',
#  'reason': 'SUCCESS',
#  'dealStatus': 'ACCEPTED',
#  'epic': 'CC.D.CL.USS.IP',
#  'expiry': 'DFB',
#  'dealReference': 'N3J93JMWYEJTY2F',
#  'dealId': 'DIAAAAMUGHUQABA',
#  'affectedDeals': [{'dealId': 'DIAAAAMUGHUQABA', 'status': 'OPENED'}],
#  'level': 7709.1,
#  'size': 0.5,
#  'direction': 'BUY',
#  'stopLevel': None,
#  'limitLevel': None,
#  'stopDistance': None,
#  'limitDistance': None,
#  'guaranteedStop': False,
#  'trailingStop': False,
#  'profit': None,
#  'profitCurrency': None}

# %%
>>> from_date = datetime(2023 , 1 , 1)
>>> activities = ig_service.fetch_account_activity(from_date=from_date)
>>> activities
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from_date = datetime(2023)
#       2 activities = ig_service.fetch_account_activity(from_date=from_date)
#       3 activities
#
# TypeError: 'module' object is not callable

# %%
>>> from trading_ig import IGService, IGStreamService
>>> from trading_ig.config import config
>>> from trading_ig.lightstreamer import Subscription

# %%
>>> def on_update(item):
>>>     print("{UPDATE_TIME:<8} {stock_name:<19} Bid {BID:>5} Ask {OFFER:>5}".format(stock_name=item["name"], **item["values"]))

# %%
>>> ig_service = IGService(config.username, config.password, config.api_key, config.acc_type, acc_number=config.acc_number)
>>> ig_stream_service = IGStreamService(ig_service)
>>> ig_stream_service.create_session()
>>> sub = Subscription(mode="MERGE", items=["L1:CC.D.CL.USS.IP"], fields=["UPDATE_TIME", "BID", "OFFER"])
>>> sub.addlistener(on_update)
>>> ig_stream_service.ls_client.subscribe(sub)
>>> ig_stream_service.disconnect()
# Out:
# DISCONNECTED FROM LIGHTSTREAMER
