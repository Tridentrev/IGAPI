# %%
import numpy as np
import pandas as pd
import requests
import xlsxwriter
import math
import datetime
import socket

# %%
>>> from trading_ig.rest import IGService
>>> from trading_ig.config import config
>>> ig_service = IGService(config.username, config.password, config.api_key)
>>> ig = ig_service.create_session()
>>> ig
# Out:
# {'accountType': 'SPREADBET',
#  'accountInfo': {'balance': 5021.7,
#   'deposit': 0.0,
#   'profitLoss': 0.0,
#   'available': 5021.7},
#  'currencyIsoCode': 'GBP',
#  'currencySymbol': '£',
#  'currentAccountId': 'Z550FI',
#  'lightstreamerEndpoint': 'https://demo-apd.marketdatasystems.com',
#  'accounts': [{'accountId': 'Z550FH',
#    'accountName': 'CFD',
#    'preferred': False,
#    'accountType': 'CFD'},
#   {'accountId': 'Z550FI',
#    'accountName': 'Spread bet',
#    'preferred': True,
#    'accountType': 'SPREADBET'}],
#  'clientId': '103631951',
#  'timezoneOffset': 1,
#  'hasActiveDemoAccounts': True,
#  'hasActiveLiveAccounts': True,
#  'trailingStopsEnabled': False,
#  'reroutingEnvironment': None,
#  'dealingEnabled': True}

# %%
>>> results = ig_service.search_markets("oil")
>>> results
# Out:
#                     epic                                     instrumentName  \
# 0    EC.D.OILFP.DAILY.IP  Lyxor Index Fund - Lyxor Stoxx Europe 600 Oil ...
# 1      EC.D.OILFP.SEP.IP  Lyxor Index Fund - Lyxor Stoxx Europe 600 Oil ...
# 2      EC.D.OILFP.DEC.IP  Lyxor Index Fund - Lyxor Stoxx Europe 600 Oil ...
# 3      EC.D.OILFP.MAR.IP  Lyxor Index Fund - Lyxor Stoxx Europe 600 Oil ...
# 4         CC.D.CL.USS.IP                                     Oil - US Crude
# 5      EN.D.CL.Month2.IP                                     Oil - US Crude
# 6      EN.D.CL.Month1.IP                                     Oil - US Crude
# 7     EN.D.LCO.Month2.IP                                  Oil - Brent Crude
# 8     EN.D.LCO.Month4.IP                                  Oil - Brent Crude
# 9        CC.D.LCO.USS.IP                                  Oil - Brent Crude
# 10     EN.D.HO.Month1.IP                                        Heating Oil
# 11        CC.D.HO.USS.IP                                        Heating Oil
# 12   ED.D.O2CGY.DAILY.IP                                         CAT Oil AG
# 13     ED.D.O2CGY.SEP.IP                                         CAT Oil AG
# 14     ED.D.O2CGY.DEC.IP                                         CAT Oil AG
# 15     ED.D.O2CGY.MAR.IP                                         CAT Oil AG
# 16      CC.D.FCPO.USS.IP                                     Crude Palm Oil
# 17     CO.D.BO.Month2.IP                                        Soybean Oil
# 18     KC.D.GOO.DAILY.IP                                      Baron Oil PLC
# 19       KC.D.GOO.SEP.IP                                      Baron Oil PLC
# 20       KC.D.GOO.DEC.IP                                      Baron Oil PLC
# 21       KC.D.GOO.MAR.IP                                      Baron Oil PLC
# 22     KC.D.JKX.DAILY.IP                                  JKX Oil & Gas PLC
# 23       KC.D.JKX.SEP.IP                                  JKX Oil & Gas PLC
# 24       KC.D.JKX.DEC.IP                                  JKX Oil & Gas PLC
# 25       KC.D.JKX.MAR.IP                                  JKX Oil & Gas PLC
# 26   SE.D.MVOUS.DAILY.IP                                       MV Oil Trust
# 27     SE.D.MVOUS.SEP.IP                                       MV Oil Trust
# 28     SE.D.MVOUS.DEC.IP                                       MV Oil Trust
# 29     SE.D.MVOUS.MAR.IP                                       MV Oil Trust
# 30   EB.D.NES1V.DAILY.IP                                      Neste Oil OYJ
# 31     EB.D.NES1V.SEP.IP                                      Neste Oil OYJ
# 32     EB.D.NES1V.DEC.IP                                      Neste Oil OYJ
# 33     EB.D.NES1V.MAR.IP                                      Neste Oil OYJ
# 34  KC.D.ENEGLN.DAILY.IP                                 Nu-Oil And Gas PLC
# 35    KC.D.ENEGLN.SEP.IP                                 Nu-Oil And Gas PLC
# 36    KC.D.ENEGLN.DEC.IP                                 Nu-Oil And Gas PLC
# 37    KC.D.ENEGLN.MAR.IP                                 Nu-Oil And Gas PLC
# 38  EH.D.TETYSS.DAILY.IP                               Tethys Oil AB (publ)
# 39    EH.D.TETYSS.SEP.IP                               Tethys Oil AB (publ)
# 40    EH.D.TETYSS.DEC.IP                               Tethys Oil AB (publ)
# 41    EH.D.TETYSS.MAR.IP                               Tethys Oil AB (publ)
# 42     KA.D.TLW.DAILY.IP                                     Tullow Oil PLC
# 43       KA.D.TLW.SEP.IP                                     Tullow Oil PLC
# 44       KA.D.TLW.DEC.IP                                     Tullow Oil PLC
# 45       KA.D.TLW.MAR.IP                                     Tullow Oil PLC
# 46   EE.D.TLWID.DAILY.IP                   Tullow Oil PLC (Euronext Dublin)
# 47     EE.D.TLWID.SEP.IP                   Tullow Oil PLC (Euronext Dublin)
# 48     EE.D.TLWID.DEC.IP                   Tullow Oil PLC (Euronext Dublin)
# 49     EE.D.TLWID.MAR.IP                   Tullow Oil PLC (Euronext Dublin)
#
#    instrumentType  expiry        high         low  percentageChange  \
# 0          SHARES     DFB   5527.0000   5440.0000              0.44
# 1          SHARES  SEP-23   5574.0000   5475.0000              0.44
# 2          SHARES  DEC-23   5634.0000   5523.0000              0.44
# 3          SHARES  MAR-24   5697.0000   5568.0000              0.43
# 4     COMMODITIES     DFB   7720.1000   7669.6000              0.42
# 5     COMMODITIES  AUG-23   7736.5000   7678.5000              0.44
# 6     COMMODITIES  SEP-23   7718.5000   7666.0000              0.38
# 7     COMMODITIES  SEP-23   8177.5000   8128.5000              0.37
# 8     COMMODITIES  OCT-23   8140.0000   8091.5000              0.36
# 9     COMMODITIES     DFB   8158.2000   8112.2000              0.38
# 10    COMMODITIES  AUG-23  26212.0000  26075.0000              0.28
# 11    COMMODITIES     DFB  26176.0000  26055.0000              0.28
# 12         SHARES     DFB    228.5700    219.4500              0.00
# 13         SHARES  SEP-23    230.4800    220.8400             -0.00
# 14         SHARES  DEC-23    232.9700    222.7800              0.00
# 15         SHARES  MAR-24    235.5700    224.5900             -0.00
# 16    COMMODITIES     DFB   3886.4000   3814.5000              0.21
# 17    COMMODITIES  AUG-23   6568.0000   6568.0000              0.00
# 18         SHARES     DFB      0.0953      0.0897              0.00
# 19         SHARES  SEP-23      0.0965      0.0904              0.01
# 20         SHARES  DEC-23      0.0979      0.0916             -0.00
# 21         SHARES  MAR-24      0.0993      0.0927             -0.01
# 22         SHARES     DFB     40.8900     40.6100              0.00
# 23         SHARES  SEP-23     41.4100     40.9200              0.00
# 24         SHARES  DEC-23     42.0100     41.4300              0.00
# 25         SHARES  MAR-24     42.6300     41.9200              0.00
# 26         SHARES     DFB   1387.1000   1336.0000              3.17
# 27         SHARES  SEP-23   1404.5000   1347.4000              3.14
# 28         SHARES  DEC-23   1425.6000   1364.9000              3.09
# 29         SHARES  MAR-24   1447.5000   1381.7000              3.05
# 30         SHARES     DFB   3651.0000   3594.0000              0.22
# 31         SHARES  SEP-23   3687.0000   3612.0000              0.22
# 32         SHARES  DEC-23   3726.0000   3643.0000              0.21
# 33         SHARES  MAR-24   3768.0000   3673.0000              0.22
# 34         SHARES     DFB         NaN         NaN              0.00
# 35         SHARES  SEP-23         NaN         NaN              0.00
# 36         SHARES  DEC-23         NaN         NaN              0.03
# 37         SHARES  MAR-24         NaN         NaN              0.00
# 38         SHARES     DFB   5007.5000   4863.8000             -1.72
# 39         SHARES  SEP-23   5049.0000   4895.0000             -1.72
# 40         SHARES  DEC-23   5104.0000   4938.0000             -1.70
# 41         SHARES  MAR-24   5161.0000   4978.0000             -1.68
# 42         SHARES     DFB     30.0000     28.5800              1.77
# 43         SHARES  SEP-23     30.3900     28.8000              1.74
# 44         SHARES  DEC-23     30.8300     29.1600              1.73
# 45         SHARES  MAR-24     31.2800     29.5000              1.71
# 46         SHARES     DFB     54.2900     54.0100              0.00
# 47         SHARES  SEP-23     54.7400     54.3600              0.00
# 48         SHARES  DEC-23     55.3300     54.8300             -0.00
# 49         SHARES  MAR-24     55.9500     55.2800              0.00
#
#     netChange updateTime updateTimeUTC         bid       offer  delayTime  \
# 0       24.00   16:35:16      15:35:16   5447.0000   5474.0000          0
# 1       24.00   16:35:16      15:35:16   5482.0000   5520.0000          0
# 2       24.00   16:35:16      15:35:16   5530.0000   5580.0000          0
# 3       24.00   16:35:16      15:35:16   5575.0000   5642.0000          0
# 4       32.10   21:59:00      20:59:00   7704.7000   7708.5000          0
# 5       33.50   21:58:57      20:58:57   7718.0000   7724.0000          0
# 6       29.50   21:58:42      20:58:42   7701.0000   7707.0000          0
# 7       30.50   21:58:42      20:58:42   8162.5000   8168.5000          0
# 8       29.00   21:58:42      20:58:42   8124.0000   8130.0000          0
# 9       30.70   21:58:45      20:58:45   8145.6000   8148.4000          0
# 10      72.00   21:58:59      20:58:59  26161.0000  26191.0000          0
# 11      73.00   21:59:02      20:59:02  26138.0000  26158.0000          0
# 12       0.00   16:35:00      15:35:00    227.4300    228.5700          0
# 13       0.00   16:35:00      15:35:00    228.8700    230.4800          0
# 14       0.00   16:35:00      15:35:00    230.8800    232.9700          0
# 15       0.00   16:35:00      15:35:00    232.7600    235.5700          0
# 16       8.20   16:29:54      15:29:54   3861.1000   3873.1000          0
# 17       0.00   19:19:59      18:19:59   6568.0000   6568.0000          0
# 18       0.00   17:00:00      16:00:00      0.0922      0.0928          0
# 19       0.00   17:00:00      16:00:00      0.0929      0.0940          0
# 20       0.00   17:00:00      16:00:00      0.0940      0.0954          0
# 21       0.00   17:00:00      16:00:00      0.0951      0.0968          0
# 22       0.00   16:30:00      15:30:00     40.6100     40.8900          0
# 23       0.00   16:30:00      15:30:00     40.9200     41.4100          0
# 24       0.00   16:30:00      15:30:00     41.4300     42.0100          0
# 25       0.00   16:30:00      15:30:00     41.9200     42.6300          0
# 26      42.00   21:00:04      20:00:04   1364.9000   1369.1000          0
# 27      42.00   21:00:04      20:00:04   1376.6000   1386.3000          0
# 28      42.00   21:00:04      20:00:04   1394.5000   1407.1000          0
# 29      42.10   21:00:04      20:00:04   1411.6000   1428.7000          0
# 30       8.00   16:30:26      15:30:26   3594.0000   3602.0000          0
# 31       8.00   16:30:26      15:30:26   3612.0000   3637.0000          0
# 32       8.00   16:30:26      15:30:26   3643.0000   3676.0000          0
# 33       8.00   16:30:27      15:30:27   3673.0000   3718.0000          0
# 34       0.00   16:30:00      15:30:00      0.0274      0.0276          0
# 35       0.00   16:30:00      15:30:00      0.0274      0.0277          0
# 36       0.00   16:30:00      15:30:00      0.0274      0.0278          0
# 37       0.00   16:30:00      15:30:00      0.0273      0.0277          0
# 38     -86.00   16:29:39      15:29:39   4887.8000   4912.3000          0
# 39     -86.00   16:29:39      15:29:39   4919.0000   4953.0000          0
# 40     -86.00   16:29:39      15:29:39   4962.0000   5007.0000          0
# 41     -86.00   16:29:39      15:29:39   5003.0000   5063.0000          0
# 42       0.52   17:00:00      16:00:00     29.7200     29.9200          0
# 43       0.52   17:00:00      16:00:00     29.9400     30.3000          0
# 44       0.52   17:00:00      16:00:00     30.3200     30.7400          0
# 45       0.52   17:00:00      16:00:00     30.6700     31.2000          0
# 46       0.00   16:30:00      15:30:00     54.0100     54.2900          0
# 47       0.00   16:30:00      15:30:00     54.3600     54.7400          0
# 48       0.00   16:30:00      15:30:00     54.8300     55.3300          0
# 49       0.00   16:30:00      15:30:00     55.2800     55.9500          0
#
#     streamingPricesAvailable marketStatus  scalingFactor
# 0                      False   EDITS_ONLY              1
# 1                      False   EDITS_ONLY              1
# 2                      False   EDITS_ONLY              1
# 3                      False   EDITS_ONLY              1
# 4                       True    TRADEABLE              1
# 5                       True    TRADEABLE              1
# 6                       True    TRADEABLE              1
# 7                       True    TRADEABLE              1
# 8                       True    TRADEABLE              1
# 9                       True    TRADEABLE              1
# 10                      True    TRADEABLE              1
# 11                      True    TRADEABLE              1
# 12                     False   EDITS_ONLY              1
# 13                     False   EDITS_ONLY              1
# 14                     False   EDITS_ONLY              1
# 15                     False   EDITS_ONLY              1
# 16                      True   EDITS_ONLY              1
# 17                      True   EDITS_ONLY              1
# 18                     False   EDITS_ONLY              1
# 19                     False   EDITS_ONLY              1
# 20                     False   EDITS_ONLY              1
# 21                     False   EDITS_ONLY              1
# 22                     False       CLOSED              1
# 23                     False       CLOSED              1
# 24                     False       CLOSED              1
# 25                     False       CLOSED              1
# 26                     False   EDITS_ONLY              1
# 27                     False   EDITS_ONLY              1
# 28                     False   EDITS_ONLY              1
# 29                     False   EDITS_ONLY              1
# 30                     False   EDITS_ONLY              1
# 31                     False   EDITS_ONLY              1
# 32                     False   EDITS_ONLY              1
# 33                     False   EDITS_ONLY              1
# 34                     False       CLOSED              1
# 35                     False       CLOSED              1
# 36                     False       CLOSED              1
# 37                     False       CLOSED              1
# 38                     False   EDITS_ONLY              1
# 39                     False   EDITS_ONLY              1
# 40                     False   EDITS_ONLY              1
# 41                     False   EDITS_ONLY              1
# 42                     False   EDITS_ONLY              1
# 43                     False   EDITS_ONLY              1
# 44                     False   EDITS_ONLY              1
# 45                     False   EDITS_ONLY              1
# 46                     False       CLOSED              1
# 47                     False       CLOSED              1
# 48                     False       CLOSED              1
# 49                     False       CLOSED              1

# %%
>>> market = ig_service.fetch_market_by_epic('CC.D.CL.USS.IP')
>>> market
# Out:
# Munch({'instrument': Munch({'epic': 'CC.D.CL.USS.IP', 'expiry': 'DFB', 'name': 'Oil - US Crude', 'forceOpenAllowed': True, 'stopsLimitsAllowed': True, 'lotSize': 1.0, 'unit': 'AMOUNT', 'type': 'COMMODITIES', 'controlledRiskAllowed': True, 'streamingPricesAvailable': True, 'marketId': 'CL', 'currencies': [Munch({'code': 'GBP', 'symbol': '£', 'baseExchangeRate': 1.0, 'exchangeRate': 1.0, 'isDefault': True}), Munch({'code': 'EUR', 'symbol': 'E', 'baseExchangeRate': 1.17006, 'exchangeRate': 0.9, 'isDefault': False}), Munch({'code': 'USD', 'symbol': '$', 'baseExchangeRate': 1.313545, 'exchangeRate': 0.66, 'isDefault': False})], 'sprintMarketsMinimumExpiryTime': None, 'sprintMarketsMaximumExpiryTime': None, 'marginDepositBands': [Munch({'min': 0, 'max': 700, 'margin': 10, 'currency': 'USD'}), Munch({'min': 700, 'max': 1400, 'margin': 10, 'currency': 'USD'}), Munch({'min': 1400, 'max': 2100, 'margin': 10, 'currency': 'USD'}), Munch({'min': 2100, 'max': None, 'margin': 15, 'currency': 'USD'})], 'marginFactor': 10, 'marginFactorUnit': 'PERCENTAGE', 'slippageFactor': Munch({'unit': 'pct', 'value': 100.0}), 'limitedRiskPremium': Munch({'value': 6, 'unit': 'POINTS'}), 'openingHours': None, 'expiryDetails': Munch({'lastDealingDate': '2029-04-06T22:59'}), 'rolloverDetails': None, 'newsCode': 'CRU', 'chartCode': None, 'country': None, 'valueOfOnePip': None, 'onePipMeans': None, 'contractSize': None, 'specialInfo': ['DEFAULT KNOCK OUT LEVEL DISTANCE', 'MIN KNOCK OUT LEVEL DISTANCE', 'MAX KNOCK OUT LEVEL DISTANCE']}), 'dealingRules': Munch({'minStepDistance': Munch({'unit': 'POINTS', 'value': 10.0}), 'minDealSize': Munch({'unit': 'POINTS', 'value': 0.5}), 'minControlledRiskStopDistance': Munch({'unit': 'POINTS', 'value': 10.0}), 'minNormalStopOrLimitDistance': Munch({'unit': 'POINTS', 'value': 6.0}), 'maxStopOrLimitDistance': Munch({'unit': 'POINTS', 'value': 10000.0}), 'controlledRiskSpacing': Munch({'unit': 'POINTS', 'value': 20.0}), 'marketOrderPreference': 'AVAILABLE_DEFAULT_OFF', 'trailingStopsPreference': 'AVAILABLE'}), 'snapshot': Munch({'marketStatus': 'TRADEABLE', 'netChange': 32.2, 'percentageChange': 0.42, 'updateTime': '20:59:10', 'delayTime': 0, 'bid': 7705.3, 'offer': 7708.1, 'high': 7720.1, 'low': 7669.6, 'binaryOdds': None, 'decimalPlacesFactor': 1, 'scalingFactor': 1, 'controlledRiskExtraSpread': 4})})

# %%
>>> result = ig_service.fetch_historical_prices_by_epic(epic='CC.D.CL.USS.IP')
>>> result['prices']
# Out:
#                         bid                             ask                  \
#                        Open    High     Low   Close    Open    High     Low
# DateTime
# 2023-07-13 23:24:00  7707.4  7708.3  7707.4  7707.8  7710.2  7711.6  7710.2
# 2023-07-13 23:25:00  7707.7  7707.7  7706.8  7707.3  7710.5  7710.6  7710.1
# 2023-07-13 23:26:00  7706.3  7708.8  7705.8  7708.8  7709.1  7711.6  7709.1
# 2023-07-13 23:27:00  7707.8  7708.8  7707.8  7708.8     NaN     NaN     NaN
# 2023-07-13 23:28:00  7709.7  7709.8  7709.7  7709.8  7712.5  7713.6  7712.5
# 2023-07-13 23:29:00  7710.3  7710.3  7710.3  7710.3  7713.1  7713.1  7713.1
# 2023-07-13 23:30:00  7709.3  7712.4  7709.3  7710.8  7712.1  7715.7  7712.1
# 2023-07-13 23:31:00  7711.3  7711.3  7708.8  7709.3  7714.1  7714.5  7712.1
# 2023-07-13 23:32:00  7708.7  7709.3  7708.3  7708.3  7712.5  7712.5  7712.1
# 2023-07-13 23:33:00  7707.3  7708.3  7706.7  7708.3  7711.1  7711.1  7709.5
#
#
#                       Close
# DateTime
# 2023-07-13 23:24:00  7710.6
# 2023-07-13 23:25:00  7710.1
# 2023-07-13 23:26:00  7711.6
# 2023-07-13 23:27:00     NaN
# 2023-07-13 23:28:00  7713.6
# 2023-07-13 23:29:00  7713.1
# 2023-07-13 23:30:00  7714.6
# 2023-07-13 23:31:00  7712.1
# 2023-07-13 23:32:00  7712.1
# 2023-07-13 23:33:00  7711.1

# %%
>>> resp = ig_service.create_open_position(
        currency_code='GBP',
        direction='BUY',
        epic='CC.D.CL.USS.IP',
        order_type='MARKET',
        expiry='DFB',
        force_open='false',
        guaranteed_stop='false',
        size=0.5, level=None,
        limit_distance=None,
        limit_level=None,
        quote_id=None,
        stop_level=None,
        stop_distance=None,
        trailing_stop=None,
        trailing_stop_increment=None)
>>> resp
# Out:
# {'date': '2023-07-13T20:56:20.957',
#  'status': 'OPEN',
#  'reason': 'SUCCESS',
#  'dealStatus': 'ACCEPTED',
#  'epic': 'CC.D.CL.USS.IP',
#  'expiry': 'DFB',
#  'dealReference': 'N3J93JMWYEJTY2F',
#  'dealId': 'DIAAAAMUGHUQABA',
#  'affectedDeals': [{'dealId': 'DIAAAAMUGHUQABA', 'status': 'OPENED'}],
#  'level': 7709.1,
#  'size': 0.5,
#  'direction': 'BUY',
#  'stopLevel': None,
#  'limitLevel': None,
#  'stopDistance': None,
#  'limitDistance': None,
#  'guaranteedStop': False,
#  'trailingStop': False,
#  'profit': None,
#  'profitCurrency': None}

# %%
>>> from_date = datetime(2023 , 1 , 1)
>>> activities = ig_service.fetch_account_activity(from_date=from_date)
>>> activities
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from_date = datetime(2023)
#       2 activities = ig_service.fetch_account_activity(from_date=from_date)
#       3 activities
#
# TypeError: 'module' object is not callable

# %%
>>> from trading_ig import IGService, IGStreamService
>>> from trading_ig.config import config
>>> from trading_ig.lightstreamer import Subscription

# %%
>>> def on_update(item):
>>>     print("{UPDATE_TIME:<8} {stock_name:<19} Bid {BID:>5} Ask {OFFER:>5}".format(stock_name=item["name"], **item["values"]))

# %%
>>> ig_service = IGService(config.username, config.password, config.api_key, config.acc_type, acc_number=config.acc_number)
>>> ig_stream_service = IGStreamService(ig_service)
>>> ig_stream_service.create_session()
>>> sub = Subscription(mode="MERGE", items=["L1:CC.D.CL.USS.IP"], fields=["UPDATE_TIME", "BID", "OFFER"])
>>> sub.addlistener(on_update)
>>> ig_stream_service.ls_client.subscribe(sub)
>>> ig_stream_service.disconnect()
# Out:
# DISCONNECTED FROM LIGHTSTREAMER
