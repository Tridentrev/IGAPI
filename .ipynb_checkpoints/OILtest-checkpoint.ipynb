# %%
import numpy as np
import pandas as pd
import requests
import xlsxwriter
import math
import datetime
import socket
from datetime import datetime, timedelta
import requests_cache

# %%
>>> from trading_ig.rest import IGService
>>> from trading_ig.config import config
>>> ig_service = IGService(config.username, config.password, config.api_key)
>>> ig = ig_service.create_session()
>>> ig
# Out:
# {'accountType': 'SPREADBET',
#  'accountInfo': {'balance': 1047.81,
#   'deposit': 388.8,
#   'profitLoss': -12.4,
#   'available': 646.61},
#  'currencyIsoCode': 'GBP',
#  'currencySymbol': '£',
#  'currentAccountId': 'Z550FI',
#  'lightstreamerEndpoint': 'https://demo-apd.marketdatasystems.com',
#  'accounts': [{'accountId': 'Z550FH',
#    'accountName': 'CFD',
#    'preferred': False,
#    'accountType': 'CFD'},
#   {'accountId': 'Z550FI',
#    'accountName': 'Spread bet',
#    'preferred': True,
#    'accountType': 'SPREADBET'}],
#  'clientId': '103631951',
#  'timezoneOffset': 1,
#  'hasActiveDemoAccounts': True,
#  'hasActiveLiveAccounts': True,
#  'trailingStopsEnabled': False,
#  'reroutingEnvironment': None,
#  'dealingEnabled': True}

# %%
>>> results = ig_service.search_markets("oil")
>>> results
# Out:
#                     epic                                     instrumentName  \
# 0    EC.D.OILFP.DAILY.IP  Amundi STOXX Euro 600 Engy ESG Scrnd UCITS ETF...
# 1      EC.D.OILFP.JUN.IP  Amundi STOXX Euro 600 Engy ESG Scrnd UCITS ETF...
# 2      EC.D.OILFP.SEP.IP  Amundi STOXX Euro 600 Engy ESG Scrnd UCITS ETF...
# 3      EC.D.OILFP.DEC.IP  Amundi STOXX Euro 600 Engy ESG Scrnd UCITS ETF...
# 4         CC.D.CL.USS.IP                                     Oil - US Crude
# 5      EN.D.CL.Month3.IP                                     Oil - US Crude
# 6      EN.D.CL.Month2.IP                                     Oil - US Crude
# 7     EN.D.LCO.Month2.IP                                  Oil - Brent Crude
# 8     EN.D.LCO.Month4.IP                                  Oil - Brent Crude
# 9        CC.D.LCO.USS.IP                                  Oil - Brent Crude
# 10     EN.D.HO.Month1.IP                                        Heating Oil
# 11     EN.D.HO.Month2.IP                                        Heating Oil
# 12        CC.D.HO.USS.IP                                        Heating Oil
# 13   ED.D.O2CGY.DAILY.IP                                         CAT Oil AG
# 14     ED.D.O2CGY.JUN.IP                                         CAT Oil AG
# 15     ED.D.O2CGY.SEP.IP                                         CAT Oil AG
# 16     ED.D.O2CGY.DEC.IP                                         CAT Oil AG
# 17      CC.D.FCPO.USS.IP                                     Crude Palm Oil
# 18     CO.D.BO.Month3.IP                                        Soybean Oil
# 19     KC.D.GOO.DAILY.IP                                      Baron Oil PLC
# 20       KC.D.GOO.JUN.IP                                      Baron Oil PLC
# 21       KC.D.GOO.SEP.IP                                      Baron Oil PLC
# 22       KC.D.GOO.DEC.IP                                      Baron Oil PLC
# 23     KC.D.JKX.DAILY.IP                                  JKX Oil & Gas PLC
# 24       KC.D.JKX.JUN.IP                                  JKX Oil & Gas PLC
# 25       KC.D.JKX.SEP.IP                                  JKX Oil & Gas PLC
# 26       KC.D.JKX.DEC.IP                                  JKX Oil & Gas PLC
# 27   SE.D.MVOUS.DAILY.IP                                       MV Oil Trust
# 28     SE.D.MVOUS.JUN.IP                                       MV Oil Trust
# 29     SE.D.MVOUS.SEP.IP                                       MV Oil Trust
# 30     SE.D.MVOUS.DEC.IP                                       MV Oil Trust
# 31   EB.D.NES1V.DAILY.IP                                      Neste Oil OYJ
# 32     EB.D.NES1V.JUN.IP                                      Neste Oil OYJ
# 33     EB.D.NES1V.SEP.IP                                      Neste Oil OYJ
# 34     EB.D.NES1V.DEC.IP                                      Neste Oil OYJ
# 35  EH.D.TETYSS.DAILY.IP                               Tethys Oil AB (publ)
# 36    EH.D.TETYSS.JUN.IP                               Tethys Oil AB (publ)
# 37    EH.D.TETYSS.SEP.IP                               Tethys Oil AB (publ)
# 38    EH.D.TETYSS.DEC.IP                               Tethys Oil AB (publ)
# 39     KA.D.TLW.DAILY.IP                                     Tullow Oil PLC
# 40       KA.D.TLW.JUN.IP                                     Tullow Oil PLC
# 41       KA.D.TLW.SEP.IP                                     Tullow Oil PLC
# 42       KA.D.TLW.DEC.IP                                     Tullow Oil PLC
# 43   EE.D.TLWID.DAILY.IP                   Tullow Oil PLC (Euronext Dublin)
# 44     EE.D.TLWID.JUN.IP                   Tullow Oil PLC (Euronext Dublin)
# 45     EE.D.TLWID.SEP.IP                   Tullow Oil PLC (Euronext Dublin)
# 46     EE.D.TLWID.DEC.IP                   Tullow Oil PLC (Euronext Dublin)
# 47    UA.D.ATPG.DAILY.IP                                 ATP Oil & Gas Corp
# 48      UA.D.ATPG.JUN.IP                                 ATP Oil & Gas Corp
# 49      UA.D.ATPG.SEP.IP                                 ATP Oil & Gas Corp
#
#    instrumentType  expiry        high         low  percentageChange  \
# 0          SHARES     DFB   6026.0000   5978.0000             -1.03
# 1          SHARES  JUN-24   6052.0000   5992.0000             -1.02
# 2          SHARES  SEP-24   6125.0000   6052.0000             -1.01
# 3          SHARES  DEC-24   6202.0000   6109.0000             -1.00
# 4     COMMODITIES     DFB   7869.9000   7731.7000             -1.02
# 5     COMMODITIES  JUL-24   7872.0000   7732.0000             -1.01
# 6     COMMODITIES  AUG-24   7834.5000   7700.0000             -1.07
# 7     COMMODITIES  JUL-24   8294.5000   8154.0000             -0.87
# 8     COMMODITIES  AUG-24   8278.0000   8143.0000             -0.96
# 9     COMMODITIES     DFB   8280.8000   8146.8000             -0.93
# 10    COMMODITIES  JUN-24  24694.0000  24249.0000             -1.17
# 11    COMMODITIES  JUL-24  24856.0000  24411.0000             -1.19
# 12    COMMODITIES     DFB  24808.0000  24377.0000             -1.14
# 13         SHARES     DFB         NaN         NaN             -0.00
# 14         SHARES  JUN-24    220.8000    211.2000             -0.00
# 15         SHARES  SEP-24         NaN         NaN             -0.00
# 16         SHARES  DEC-24         NaN         NaN             -0.00
# 17    COMMODITIES     DFB   3958.7000   3853.5000             -2.07
# 18    COMMODITIES  JUL-24   4677.5000   4566.5000              0.38
# 19         SHARES     DFB      0.0702      0.0598             -2.99
# 20         SHARES  JUN-24      0.0707      0.0599             -2.94
# 21         SHARES  SEP-24      0.0717      0.0607             -2.94
# 22         SHARES  DEC-24      0.0728      0.0615             -2.87
# 23         SHARES     DFB     40.8900     40.6100              0.00
# 24         SHARES  JUN-24     41.1700     40.6800              0.01
# 25         SHARES  SEP-24     41.8000     41.2100             -0.00
# 26         SHARES  DEC-24     42.4500     41.7300              0.01
# 38                     False   EDITS_ONLY              1
# 39                     False   EDITS_ONLY              1
# 40                     False   EDITS_ONLY              1
# 41                     False   EDITS_ONLY              1
# 42                     False   EDITS_ONLY              1
# 43                     False       CLOSED              1
# 44                     False       CLOSED              1
# 45                     False       CLOSED              1
# 46                     False       CLOSED              1
# 47                     False   ON_AUCTION              1
# 48                     False   ON_AUCTION              1
# 49                     False   ON_AUCTION              1

# %%
>>> market = ig_service.fetch_market_by_epic('CC.D.CL.USS.IP')
>>> market
# Out:
# Munch({'instrument': Munch({'epic': 'CC.D.CL.USS.IP', 'expiry': 'DFB', 'name': 'Oil - US Crude', 'forceOpenAllowed': True, 'stopsLimitsAllowed': True, 'lotSize': 1.0, 'unit': 'AMOUNT', 'type': 'COMMODITIES', 'controlledRiskAllowed': True, 'streamingPricesAvailable': True, 'marketId': 'CL', 'currencies': [Munch({'code': 'GBP', 'symbol': '£', 'baseExchangeRate': 1.0, 'exchangeRate': 1.0, 'isDefault': True}), Munch({'code': 'EUR', 'symbol': 'E', 'baseExchangeRate': 1.17495, 'exchangeRate': 0.9, 'isDefault': False}), Munch({'code': 'USD', 'symbol': '$', 'baseExchangeRate': 1.2734115, 'exchangeRate': 0.66, 'isDefault': False})], 'sprintMarketsMinimumExpiryTime': None, 'sprintMarketsMaximumExpiryTime': None, 'marginDepositBands': [Munch({'min': 0, 'max': 700, 'margin': 10, 'currency': 'USD'}), Munch({'min': 700, 'max': 1400, 'margin': 10, 'currency': 'USD'}), Munch({'min': 1400, 'max': 2100, 'margin': 10, 'currency': 'USD'}), Munch({'min': 2100, 'max': None, 'margin': 15, 'currency': 'USD'})], 'marginFactor': 10, 'marginFactorUnit': 'PERCENTAGE', 'slippageFactor': Munch({'unit': 'pct', 'value': 100.0}), 'limitedRiskPremium': Munch({'value': 6, 'unit': 'POINTS'}), 'openingHours': None, 'expiryDetails': Munch({'lastDealingDate': '2029-04-06T22:59'}), 'rolloverDetails': None, 'newsCode': 'CRU', 'chartCode': None, 'country': None, 'valueOfOnePip': None, 'onePipMeans': None, 'contractSize': None, 'specialInfo': ['DEFAULT KNOCK OUT LEVEL DISTANCE', 'MIN KNOCK OUT LEVEL DISTANCE', 'MAX KNOCK OUT LEVEL DISTANCE']}), 'dealingRules': Munch({'minStepDistance': Munch({'unit': 'POINTS', 'value': 10.0}), 'minDealSize': Munch({'unit': 'POINTS', 'value': 0.5}), 'minControlledRiskStopDistance': Munch({'unit': 'POINTS', 'value': 10.0}), 'minNormalStopOrLimitDistance': Munch({'unit': 'POINTS', 'value': 6.0}), 'maxStopOrLimitDistance': Munch({'unit': 'POINTS', 'value': 10000.0}), 'controlledRiskSpacing': Munch({'unit': 'POINTS', 'value': 20.0}), 'marketOrderPreference': 'AVAILABLE_DEFAULT_OFF', 'trailingStopsPreference': 'AVAILABLE'}), 'snapshot': Munch({'marketStatus': 'TRADEABLE', 'netChange': -80, 'percentageChange': -1.02, 'updateTime': '17:46:59', 'delayTime': 0, 'bid': 7774.6, 'offer': 7777.4, 'high': 7869.9, 'low': 7731.7, 'binaryOdds': None, 'decimalPlacesFactor': 1, 'scalingFactor': 1, 'controlledRiskExtraSpread': 4})})

# %%
>>> result = ig_service.fetch_historical_prices_by_epic(epic='CC.D.CL.USS.IP')
>>> result['prices']
# Out:
#                         bid                             ask                  \
#                        Open    High     Low   Close    Open    High     Low
# DateTime
# 2024-05-22 18:37:00  7782.7  7785.7  7778.6  7785.6  7785.5  7788.5  7781.4
# 2024-05-22 18:38:00  7784.7  7790.6  7784.7  7787.6  7787.5  7793.4  7787.5
# 2024-05-22 18:39:00  7786.7  7787.6  7785.6  7785.7  7789.5  7790.9  7788.5
# 2024-05-22 18:40:00  7786.6  7787.7  7783.2  7785.6  7789.4  7790.5  7786.5
# 2024-05-22 18:41:00  7785.7  7786.6  7782.6  7785.6  7788.5  7789.4  7785.5
# 2024-05-22 18:42:00  7785.7  7785.7  7782.6  7782.7  7788.5  7788.5  7785.5
# 2024-05-22 18:43:00  7781.7  7781.7  7771.7  7775.7  7784.5  7784.5  7774.5
# 2024-05-22 18:44:00  7774.7  7775.7  7766.7  7769.7  7777.5  7778.5  7769.5
# 2024-05-22 18:45:00  7768.7  7776.7  7767.8  7773.7  7771.5  7779.5  7770.6
# 2024-05-22 18:46:00  7772.7  7775.6  7772.7  7774.6  7775.5  7778.5  7775.5
#
#                             last
#                       Close Open High Low Close Volume
# DateTime
# 2024-05-22 18:37:00  7788.4  NaN  NaN NaN   NaN    156
# 2024-05-22 18:38:00  7790.4  NaN  NaN NaN   NaN    271
# 2024-05-22 18:39:00  7788.5  NaN  NaN NaN   NaN    120
# 2024-05-22 18:40:00  7788.4  NaN  NaN NaN   NaN    115
# 2024-05-22 18:41:00  7788.4  NaN  NaN NaN   NaN    143
# 2024-05-22 18:42:00  7785.5  NaN  NaN NaN   NaN    173
# 2024-05-22 18:43:00  7778.5  NaN  NaN NaN   NaN    500
# 2024-05-22 18:44:00  7772.5  NaN  NaN NaN   NaN    298
# 2024-05-22 18:45:00  7776.5  NaN  NaN NaN   NaN    486
# 2024-05-22 18:46:00  7777.4  NaN  NaN NaN   NaN    199

# %%
>>> resp = ig_service.create_open_position(
        currency_code='GBP',
        direction='SELL',
        epic='CC.D.CL.USS.IP',
        order_type='MARKET',
        expiry='DFB',
        force_open='false',
        guaranteed_stop='false',
        size=0.5, level=None,
        limit_distance=None,
        limit_level=None,
        quote_id=None,
        stop_level=None,
        stop_distance=None,
        trailing_stop=None,
        trailing_stop_increment=None)
>>> resp
# Out:
# {'date': '2024-05-22T18:15:07.308',
#  'status': 'CLOSED',
#  'reason': 'SUCCESS',
#  'dealStatus': 'ACCEPTED',
#  'epic': 'CC.D.CL.USS.IP',
#  'expiry': 'DFB',
#  'dealReference': 'GLV6TYV7PDLTYM9',
#  'dealId': 'DIAAAAP22SNU7AE',
#  'affectedDeals': [{'dealId': 'DIAAAAP22SNU7AE', 'status': 'FULLY_CLOSED'}],
#  'level': 7759.6,
#  'size': 0.5,
#  'direction': 'SELL',
#  'stopLevel': None,
#  'limitLevel': None,
#  'stopDistance': None,
#  'limitDistance': None,
#  'guaranteedStop': False,
#  'trailingStop': False,
#  'profit': -19.95,
#  'profitCurrency': 'GBP'}

# %%
from_date = datetime(2024, 1, 1)
activities = ig_service.fetch_account_activity(from_date=from_date)
activities
# Out:
#                    date                  epic period           dealId  \
# 0   2024-05-22T17:47:01        CC.D.CL.USS.IP    DFB  DIAAAAP22UN94BC
# 1   2024-05-22T17:27:59        CC.D.CL.USS.IP    DFB  DIAAAAP22SNU7AE
# 2   2024-05-16T13:18:03        CC.D.CL.USS.IP    DFB  DIAAAAPZK27ULAC
# 3   2024-05-15T23:51:11        CC.D.CL.USS.IP    DFB  DIAAAAPZK2Y4NAG
# 4   2024-05-08T23:49:43  CS.D.GBPCAD.TODAY.IP    DFB  DIAAAAPXUM3E5AB
# 5   2024-05-08T23:10:16        CC.D.CL.USS.IP    DFB  DIAAAAPXULJC4AE
# 6   2024-05-08T23:10:01        CC.D.CL.USS.IP    DFB  DIAAAAPXULPZ9A2
# 7   2024-04-05T13:47:13        CC.D.CL.USS.IP    DFB  DIAAAAPPX4V9WAM
# 8   2024-04-05T12:59:32        CC.D.CL.USS.IP    DFB  DIAAAAPPX5HR4A2
# 9   2024-04-03T16:46:52        CC.D.CL.USS.IP    DFB  DIAAAAPN9Z2WWAM
# 10  2024-04-03T14:30:40        CC.D.CL.USS.IP    DFB  DIAAAAPN92FC8AU
# 11  2024-03-27T18:34:43        CC.D.CL.USS.IP    DFB  DIAAAAPMKTPWGA7
# 12  2024-03-27T17:02:11        CC.D.CL.USS.IP    DFB  DIAAAAPMKT26UAS
# 13  2024-03-27T14:33:50        CC.D.CL.USS.IP    DFB  DIAAAAPMKJLREA7
# 14  2024-03-27T14:30:34        CC.D.CL.USS.IP    DFB  DIAAAAPMKJLQ7A7
# 15  2024-03-22T13:38:17        CC.D.CL.USS.IP    DFB  DIAAAAPLK48VEAT
# 16  2024-03-22T13:00:27        CC.D.CL.USS.IP    DFB  DIAAAAPLK5WCYBC
# 17  2024-03-22T12:56:32  CS.D.GBPCAD.TODAY.IP    DFB  DIAAAAPLK3W5CAT
# 18  2024-03-22T12:30:10  CS.D.GBPCAD.TODAY.IP    DFB  DIAAAAPLK25EQA6
# 19  2024-03-20T10:29:26  CS.D.GBPCAD.TODAY.IP    DFB  DIAAAAPK4XSXJBC
# 20  2024-03-20T07:00:36  CS.D.GBPCAD.TODAY.IP    DFB  DIAAAAPK4JM5RA2
# 21  2024-03-18T07:18:10        CC.D.CL.USS.IP    DFB  DIAAAAPJ6M626AT
# 22  2024-03-18T02:15:33        CC.D.CL.USS.IP    DFB  DIAAAAPJ6SP5WA4
# 23  2024-03-18T01:00:17        CC.D.CL.USS.IP    DFB  DIAAAAPJ6MZ78A5
# 24  2024-03-15T15:12:27        CC.D.CL.USS.IP    DFB  DIAAAAPJ46NUWAT
# 25  2024-03-15T15:03:32        CC.D.CL.USS.IP    DFB  DIAAAAPJ5DHG3A2
# 26  2024-03-15T14:11:00        CC.D.CL.USS.IP    DFB  DIAAAAPJ4758TA8
# 27  2024-03-15T14:00:10        CC.D.CL.USS.IP    DFB  DIAAAAPJ46DYFAP
#
#            channel                 type    status  \
# 0   PUBLIC_WEB_API             POSITION  ACCEPTED
# 1   PUBLIC_WEB_API             POSITION  ACCEPTED
# 2           SYSTEM             POSITION  ACCEPTED
# 3              WEB             POSITION  ACCEPTED
# 4              WEB             POSITION  REJECTED
# 5              WEB             POSITION  ACCEPTED
# 6              WEB             POSITION  ACCEPTED
# 7           SYSTEM             POSITION  ACCEPTED
# 8           SYSTEM             POSITION  ACCEPTED
# 9           SYSTEM             POSITION  ACCEPTED
# 10             WEB             POSITION  ACCEPTED
# 11          SYSTEM             POSITION  ACCEPTED
# 12             WEB             POSITION  ACCEPTED
# 13          SYSTEM             POSITION  ACCEPTED
# 14             WEB             POSITION  ACCEPTED
# 15          SYSTEM             POSITION  ACCEPTED
# 16             WEB             POSITION  ACCEPTED
# 17          SYSTEM             POSITION  ACCEPTED
# 18             WEB             POSITION  ACCEPTED
# 19             WEB             POSITION  ACCEPTED
# 20             WEB             POSITION  ACCEPTED
# 21          SYSTEM             POSITION  ACCEPTED
# 22          SYSTEM  EDIT_STOP_AND_LIMIT  ACCEPTED
# 23             WEB             POSITION  ACCEPTED
# 24          SYSTEM             POSITION  ACCEPTED
# 25          SYSTEM  EDIT_STOP_AND_LIMIT  ACCEPTED
# 26          SYSTEM  EDIT_STOP_AND_LIMIT  ACCEPTED
# 27             WEB             POSITION  ACCEPTED
#
#                      description details
# 0      Position opened: 22UN94BC    None
# 1      Position opened: 22SNU7AE    None
# 2    Position/s closed: ZK2Y4NAG    None
# 3      Position opened: ZK2Y4NAG    None
# 4   Rejected: Insufficient funds    None
# 5    Position/s closed: XULPZ9A2    None
# 6      Position opened: XULPZ9A2    None
# 7    Position/s closed: PX5HR4A2    None
# 8      Position opened: PX5HR4A2    None
# 9    Position/s closed: N92FC8AU    None
# 10     Position opened: N92FC8AU    None
# 11   Position/s closed: MKT26UAS    None
# 12     Position opened: MKT26UAS    None
# 13   Position/s closed: MKJLQ7A7    None
# 14     Position opened: MKJLQ7A7    None
# 15   Position/s closed: LK5WCYBC    None
# 16     Position opened: LK5WCYBC    None
# 17   Position/s closed: LK25EQA6    None
# 18     Position opened: LK25EQA6    None
# 19   Position/s closed: K4JM5RA2    None
# 20     Position opened: K4JM5RA2    None
# 21   Position/s closed: J6MZ78A5    None
# 22  Stop/Limit amended: J6MZ78A5    None
# 23     Position opened: J6MZ78A5    None
# 24   Position/s closed: J46DYFAP    None
# 25  Stop/Limit amended: J46DYFAP    None
# 26  Stop/Limit amended: J46DYFAP    None
# 27     Position opened: J46DYFAP    None

# %%
>>> from trading_ig import IGService, IGStreamService
>>> from trading_ig.config import config
>>> from trading_ig.lightstreamer import Subscription

# %%
>>> def on_update(item):
>>>     print("{UPDATE_TIME:<8} {stock_name:<19} Bid {BID:>5} Ask {OFFER:>5}".format(stock_name=item["name"], **item["values"]))

# %%
>>> ig_service = IGService(config.username, config.password, config.api_key, config.acc_type, acc_number=config.acc_number)
>>> ig_stream_service = IGStreamService(ig_service)
>>> ig_stream_service.create_session()
>>> sub = Subscription(mode="MERGE", items=["L1:CC.D.CL.USS.IP"], fields=["UPDATE_TIME", "BID", "OFFER"])
>>> sub.addlistener(on_update)
>>> ig_stream_service.ls_client.subscribe(sub)
>>> ig_stream_service.disconnect()
# Out:
# 18:51:00 L1:CC.D.CL.USS.IP   Bid 7768.6 Ask 7771.4
# DISCONNECTED FROM LIGHTSTREAMER
